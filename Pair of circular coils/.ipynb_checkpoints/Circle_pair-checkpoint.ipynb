# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import matplotlib.ticker as ticker

from biot_savart_v4_3 import *

# %%
helmholtz_coils("coil1.txt", "coil2.txt", numSegments = 50, radius = 9.5, spacing = 16.5, current = 1)

# %%
write_target_volume("coil1.txt", "targetvol1", (40, 40, 20), (-20, -20, -10), 0.4, 0.4)
write_target_volume("coil2.txt", "targetvol2", (40, 40, 20), (-20, -20, -10), 0.4, 0.4)
# generates a target volume from the coil stored at coil.txt
# uses a (40, 40, 20) bounding box, starting at (-20, -20, -10)
# uses 0.5 cm resolution

# %%
plot_coil("coil1.txt", "coil2.txt")
# plots the coil stored at coil.txt

# %%
h1 = read_target_volume("targetvol1")
h2 = read_target_volume("targetvol2")
# reads the volume we created

# %%
h_total = h1 + h2

# %%
plot_fields(h_total, (40, 40, 20), (-20, -20, -10), 0.4, which_plane='z', level=0, num_contours=1)
